# %%
import pandas as pd

df = pd.read_csv("per_day_participant_dataset.csv")

# %%
df.head(5)
# Out:
#                                 Unnamed: 0   mood  mood_count  \
# 0  ('AS14.01', datetime.date(2014, 2, 26))   25.0           4
# 1  ('AS14.01', datetime.date(2014, 2, 27))   44.0           7
# 2  ('AS14.01', datetime.date(2014, 3, 21))   75.0          12
# 3  ('AS14.01', datetime.date(2014, 3, 22))  107.0          17
# 4  ('AS14.01', datetime.date(2014, 3, 23))  141.0          22
#
#    circumplex.arousal  circumplex.arousal_count  circumplex.valence  \
# 0                -1.0                         4                 3.0
# 1                -1.0                         7                 4.0
# 2                 0.0                        12                 5.0
# 3                 3.0                        17                 NaN
# 4                 4.0                        22                 NaN
#
#    circumplex.valence_count  activity  activity_count        screen  ...  \
# 0                         4  0.000000               0      0.000000  ...
# 1                         7  0.000000               0      0.000000  ...
# 2                        12  3.246248              25  20254.851000  ...
# 3                        17  7.036331              41  26397.012000  ...
# 4                        22  9.177448              56  33170.844001  ...
#
#    appCat.social  appCat.social_count  appCat.travel  appCat.travel_count  \
# 0          0.000                    0          0.000                    0
# 1          0.000                    0          0.000                    0
# 2       5316.231                   71        915.445                   13
# 3       5755.863                   83        952.750                   14
# 4       6656.702                  101        952.750                   14
#
#    appCat.unknown  appCat.unknown_count  appCat.utilities  \
# 0           0.000                     0             0.000
# 1           0.000                     0             0.000
# 2          45.173                     1           619.828
# 3          45.173                     1           737.449
# 4          45.173                     1           767.535
#
#    appCat.utilities_count  appCat.weather  appCat.weather_count
# 0                       0           0.000                     0
# 1                       0           0.000                     0
# 2                      28           0.000                     0
# 3                      31           0.000                     0
# 4                      32          30.386                     1
#
# [5 rows x 39 columns]

# %%
import dataset_tools as dt

# %%
raw_df = pd.read_csv("dataset_mood_smartphone.csv")
